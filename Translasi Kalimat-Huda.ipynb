# %%
import pandas as pd
import nltk
import re
import ast
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemover, ArrayDictionary
import csv

# %%
## default awalnya - lalu cek nvidia-smi untuk tahu GPU mana yang masih minim digunakan
import torch
print(torch.cuda.current_device())
# Out:
# 0

# %%
torch.cuda.set_device(7)
print(torch.cuda.current_device())
# Out:
# 7

# %%
# !nvidia-smi
# Out:
# Thu Apr 28 00:34:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.126.02   Driver Version: 418.126.02   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   39C    P0    64W / 300W |  20135MiB / 32480MiB |      4%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   42C    P0    72W / 300W |   8878MiB / 32480MiB |     29%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   53C    P0   153W / 300W |  14142MiB / 32480MiB |     79%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   47C    P0    94W / 300W |  17761MiB / 32480MiB |     23%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM2...  On   | 00000000:85:00.0 Off |                    0 |
# | N/A   44C    P0    87W / 300W |  29261MiB / 32480MiB |     21%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM2...  On   | 00000000:86:00.0 Off |                    0 |
# | N/A   47C    P0    88W / 300W |  19682MiB / 32480MiB |     37%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM2...  On   | 00000000:89:00.0 Off |                    0 |
# | N/A   65C    P0   280W / 300W |  16405MiB / 32480MiB |    100%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                    0 |
# | N/A   38C    P0    56W / 300W |   9291MiB / 32480MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import os, sys
sys.path.append('../')
os.chdir('../')

import random
import numpy as np
import pandas as pd
import torch
from torch import optim
from tqdm import tqdm

from transformers import BertConfig, BertTokenizer
from nltk.tokenize import word_tokenize

from modules.word_classification import BertForWordClassification
from utils.forward_fn import forward_word_classification
from utils.metrics import pos_tag_metrics_fn
from utils.data_utils import PosTagIdnDataset, PosTagDataLoader
# Out:
# 2022-04-27 17:56:35.873320: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ### Pre-processing

# %%
def load_kamus():
    kamus = pd.read_csv('/workspace/BISINDO/Translation/kamus.csv',delimiter=';')
    kata_bahasa = kamus['Kata Bahasa Indonesia']
    kata_bisindo = kamus['Kata Bisindo']
    kamus_bahasa_bisindo = dict(zip(kata_bahasa, kata_bisindo))
    
    return kamus_bahasa_bisindo

# %%
print(load_kamus())
# Out:
# {'berjalan': 'jalan-kaki', 'milik': 'punya', 'anda': 'kamu', 'ceramah': 'nasehat', 'andaikan': 'kalau', 'diperkenankan': 'boleh'}

# %%
# buang tanda baca,
# buang extra whitespaces,
# ganti kata-kata sesuai dengan padanan kamus
def normalisasi(kal):
    #clean_str = kal.lower() #lowercase
    clean_str = re.sub(r'[!"#$%&\'()*+, -./:;<=>@\[\]\\^_`{|}~]', " ", kal) #buang tanda baca, kecuali tanda tanya
    list_kata = re.findall(r"[\w']+|[?]", clean_str) #memisahkan tanda baca tanya dari kata
    
    #ganti padanan di kamus
    normal_kata = []
    for kata in list_kata:
        daftar_kamus = load_kamus()
        if kata.lower() in daftar_kamus:
            kata = daftar_kamus[kata.lower()]
        normal_kata.append(kata)
    result = ' '.join(normal_kata)

    return result

# %%
normalisasi('apakah lawan kata "berat", "ringan"?')
# Out:
# 'apakah lawan kata berat ringan ?'

# %%
# prepare testing data

def change(source_file):  
    root_dir = f'/workspace/BISINDO/Translation/Huda/'
    f = open(f'{root_dir}/{source_file}', 'r')
    output_txt = open(f'{root_dir}/[test]-{source_file}', 'w')   

    mod_cnt = 0
    cnt = 0
    for kal in f:
        kal_normed = normalisasi(kal)
#         pos_seq, word_seq = extract_word_tag(kal_normed)
        word_seq = kal_normed.split()
        word_seq = filter_stop_words(word_seq)
        word_seq = filter_preposisi(word_seq)
        word_seq = stem(word_seq)
        bindo_setengah_jadi = ' '.join(word_seq)

        output_txt.write(f'{bindo_setengah_jadi}\n')

    output_txt.close()
    f.close()

# %%
# mengubah kalimat bahasa indonesia menjadi kalimat setengah jadi (tanpa imbuhan dan preposisi)

files_to_be_changed = [
    '[bindo2]-bindo368.txt'
]

for el in files_to_be_changed:
    print(f'Processing {el}...')
    change(el)
    print('=======')
# Out:
# Processing [bindo2]-bindo368.txt...
# =======

# %% [markdown]
# ### POS TAGGING PER TOKEN KATA

# %%
## model pos taggingnya menggunakan model yang sudah ditrain sebelumnya
model = torch.load('/workspace/BISINDO/POS-MODEL/model_v1/model.pth')
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.normalization.LayerNorm' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.dropout.Dropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.8/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.activation.Tanh' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
# Load Tokenizer and Config
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-large-p1')
config = BertConfig.from_pretrained('indobenchmark/indobert-large-p1')
config.num_labels = PosTagIdnDataset.NUM_LABELS

# %%
w2i, i2w = PosTagIdnDataset.LABEL2INDEX, PosTagIdnDataset.INDEX2LABEL

# %%
def word_subword_tokenize(sentence, tokenizer):
    # Add CLS token
    subwords = [tokenizer.cls_token_id]
    subword_to_word_indices = [-1] # For CLS

    # Add subwords
    for word_idx, word in enumerate(sentence):
        subword_list = tokenizer.encode(word, add_special_tokens=False)
        subword_to_word_indices += [word_idx for i in range(len(subword_list))]
        subwords += subword_list

    # Add last SEP token
    subwords += [tokenizer.sep_token_id]
    subword_to_word_indices += [-1]

    return subwords, subword_to_word_indices

# %%
def prediksi_pos_tag(kalimat):
    text = word_tokenize(kalimat)
    subwords, subword_to_word_indices = word_subword_tokenize(text, tokenizer)

    subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)
    subword_to_word_indices = torch.LongTensor(subword_to_word_indices).view(1, -1).to(model.device)
    logits = model(subwords, subword_to_word_indices)[0]

    preds = torch.topk(logits, k=1, dim=-1)[1].squeeze().cpu().numpy()
    labels = [i2w[preds[i]].split('-')[1] for i in range(len(preds))]
    return labels
    
#     #menambahkan penghubung + antar pos tag
#     string_lb = ''
#     for lb in labels:
#         string_lb += lb + "+"
    
#     #memberi indeks 2,3 dst untuk pos tag yang munculnya berulang
#     x2 = []
#     d = {}
#     for x in labels:
#         d[x] = d.get(x, 0) + 1
#         if d[x] > 1:
#             x = x + str(d[x])
#         x2.append(x)
#     str2 = '+'.join(x2)
#     string_lb = string_lb[:-1]
#     return str2

# %%
prediksi_pos_tag('memberi indeks 2 3 dst untuk pos tag yang munculnya berulang')
# Out:
# ['VB', 'NN', 'CD', 'CD', 'NN', 'IN', 'NN', 'NN', 'SC', 'NN', 'VB']

# %%
prediksi_pos_tag('kilang minyak balongan terdapat di lepas pantai')
# Out:
# ['NN', 'NN', 'NNP', 'VB', 'IN', 'JJ', 'JJ']

# %%
prediksi_pos_tag('setiap lewat tengah malam, suara itu pasti terdengar')
## no preposisi in test
# lewat
# Out:
# ['CD', 'VB', 'NN', 'NN', 'Z', 'NN', 'PR', 'RB', 'VB']

# %%
prediksi_pos_tag('harga per kilogramnya rp 17.500')
## no preposisi in test
# per
# Out:
# ['NN', 'IN', 'NND', 'SYM', 'CD']

# %%
prediksi_pos_tag('lemari dan meja serta kursi ini saya beli ketika harganya belum melambung') #serta
# Out:
# ['NN', 'CC', 'NN', 'CC', 'NN', 'PR', 'PRP', 'VB', 'SC', 'NN', 'NEG', 'VB']

# %%
prediksi_pos_tag('lelaki itu berbicara tanpa basa - basi') #tanpa
# Out:
# ['NN', 'PR', 'VB', 'IN', 'NN', 'NN', 'NN']

# %%
prediksi_pos_tag('ayah beserta ibu sedang pergi ke makassar') #beserta
# Out:
# ['NN', 'VB', 'NN', 'MD', 'VB', 'IN', 'NNP']

# %%
prediksi_pos_tag('dia selalu pergi menjelang malam apabila naik kereta ke surabaya') #menjelang
# Out:
# ['PRP', 'RB', 'VB', 'IN', 'NN', 'SC', 'VB', 'NN', 'IN', 'NNP']

# %%
prediksi_pos_tag('dua wanita itu pergi menuju ke jembatan penyebrangan') #menuju
# Out:
# ['CD', 'NN', 'PR', 'VB', 'VB', 'IN', 'NN', 'NN']

# %%
prediksi_pos_tag('sumi cantik bagaikan bidadari') #bagaikan
# Out:
# ['NNP', 'JJ', 'IN', 'NN']

# %%
prediksi_pos_tag('tari pendet berasal bali')
# Out:
# ['NN', 'NNP', 'VB', 'NNP']

# %% [markdown]
# ### Utilities (Ronaldi)

# %%
def match(pos_seq, rule):
    if 'WH' in rule and pos_seq[-1] != 'Z':
        return -1
    
    for i in range(len(pos_seq) - len(rule) + 1):
        sliced_seq = pos_seq[i:i+len(rule)]
        # print('SLICED',sliced_seq)

        if rule == ['S','CC','S']:
            first_tag = sliced_seq[0] in ['PRP', 'NN', 'NNP']
            second_tag = sliced_seq[1] == 'CC'
            third_tag = sliced_seq[2] in ['PRP', 'NN', 'NNP']
            if first_tag and second_tag and third_tag:
                return i
            else:
                continue

        if 'S' in rule:
            first_tag = sliced_seq[0]
            if first_tag in ['PRP', 'NN', 'NNP'] and sliced_seq[1:] == rule[1:]:
                return i
            else:
                continue            

        if sliced_seq == rule:
            return i
    return -1

def remove_matched_seq(seq, matched_index, removed_size):
    remaining = seq
    removed = [remaining.pop(matched_index) for i in range(removed_size)]
    return removed, remaining

def insert_transformed_seq(seq, insertion, start_index, rule):
    if not insertion:
        return seq
    elif 'WH' in rule and rule != ['WH','SC']:
        seq[-1:-1] = insertion
    else:
        seq[start_index:start_index] = insertion
    return seq

def process_seq(seq, matched_index, rule, fn):
    matched_size = len(rule)
    removed_seq, remaining_seq = remove_matched_seq(seq, matched_index, matched_size)
    result = insert_transformed_seq(remaining_seq, fn(removed_seq), matched_index, rule)
    return result

# %% [markdown]
# ### Utilities (Huda)

# %%
from nltk.util import ngrams

def ngram(kalimat, k):
#     kalimat_n = kalimat.split('\n')
#     kalimat_cleaned = ' '.join(kalimat_n[:-1])
    kalimat_split = kalimat.split(' ')
    ngram = list(ngrams(kalimat_split, n=k))
    
    return ngram

# %% [markdown]
# ### Extract Word Tag

# %% [markdown]
# modul ini digunakan untuk memisahkan pos tag, kata dan pasangan pos-tag kata

# %%
def extract_word_tag(kalimat):
    pos_word_pair = []
    pos_seq = prediksi_pos_tag(kalimat)
    word_seq = kalimat.split()
    
    for (pos,word) in zip(pos_seq,word_seq):
        pos_word_pair.append((pos,word))
    
    ### pembetulan jika terdapat kata TIDAK BOLEH, tag nya salah sehingga perlu dibetulkan
    
    matched_index = match(pos_word_pair, [('RB','tidak'), ('RB','boleh')])
    if matched_index != -1:        
        pos_seq = process_seq(pos_seq, matched_index, ['RB','RB'], lambda x: ['NEG','MD'])
        word_seq = process_seq(word_seq, matched_index, ['RB','RB'], lambda x: x)
    
    return pos_seq, word_seq

# %%
extract_word_tag('kamu tidak boleh melakukan hal itu')
# Out:
# (['PRP', 'NEG', 'MD', 'VB', 'NN', 'PR'],
#  ['kamu', 'tidak', 'boleh', 'melakukan', 'hal', 'itu'])

# %% [markdown]
# ### stemming

# %%
def stem(word_seq):
    result = []
    for i in range(len(word_seq)):
        word = word_seq[i]
        
        if word == '?':
            result.append(word)
            continue
        
        factory = StemmerFactory()
        stemmer = factory.create_stemmer()   
        stemmed_word = stemmer.stem(word)
        daftar_kamus = load_kamus()
        if stemmed_word in daftar_kamus:
            stemmed_word = daftar_kamus[stemmed_word]
        result.append(stemmed_word)
            
    return result

# %%
stem(['kamu', 'tidak', 'boleh', 'melakukan', 'hal', 'itu', '?'])
# Out:
# ['kamu', 'tidak', 'boleh', 'laku', 'hal', 'itu', '?']

# %% [markdown]
# ### filtering stop words (modifikasi)

# %%
#stopwords excluding preposisi

stopwords = [
             'kepada',
             'sedang',
             'amat', 'anu',
             'dong',
             'ialah', 'adalah',
             'kah', 'kan',
             'lah',
             'merupakan',
             'nah', 'para',
             'pihak', 'pun',
             'saja', 'sangat',
             'sangatlah', 'sebagai',
             'secara', 'sedangkan',
             'sehingga', 'selaku',
             'terdiri', 'terlalu',
             'wong', 'yaitu',
             'yakni', 'yang'
]

# %%
dictionary = ArrayDictionary(stopwords)
sw_remover = StopWordRemover(dictionary)

def filter_stop_words(word_seq):
    for i in range(len(word_seq)-1, 0, -1):
        word = word_seq[i]
        if word in stopwords:
            del word_seq[i]
    return word_seq

# %%
filter_stop_words(
    ['kamu', 'tidak', 'boleh', 'melakukan', 'hal', 'itu', 'di', 'sedang'])
# Out:
# ['kamu', 'tidak', 'boleh', 'melakukan', 'hal', 'itu', 'di']

# %% [markdown]
# ### filtering preposisi (huda)

# %%
preposisi = [
             'dari', 'sejak',
             'di', 'dalam',
             'pada', 'bagi',
             'dengan', 'atas',
             'terhadap', 'tentang',
             'untuk', 'oleh',
             'ke', 'seperti',
             'antar',
             'buat', 'guna',
             'ibarat', 'sambil',
             'bahkan', 'akan',
             'antara', 'demi',
             'hingga', 'kecuali',
             'lepas', 'lewat',
             'per', 'sampai',
             'serta', 'tanpa',
]

# %%
dictionary = ArrayDictionary(stopwords)
sw_remover = StopWordRemover(dictionary)

def filter_preposisi(word_seq):
    for i in range(len(word_seq)-1, -1, -1):
        word = word_seq[i]
        if word in preposisi:
            del word_seq[i]
    return word_seq

# %%
filter_preposisi(['di', 'kamu', 'tidak', 'boleh', 'melakukan', 'hal', 'itu', 'di', 'sedang'])
# Out:
# ['kamu', 'tidak', 'boleh', 'melakukan', 'hal', 'itu', 'sedang']

# %% [markdown]
# ### Modul untuk menghitung BLEU SCORE

# %%
import datasets
bleu = datasets.load_metric('bleu')

# %%
'''
format input bleu_score:
predictions = [
    ["hello", "there", "general", "kenobi"],                             # tokenized prediction of the first sample
    ["foo", "bar", "foobar"]                                             # tokenized prediction of the second sample
    ]
references = [
    [["hello", "there", "general", "kenobi"], ["hello", "there", "!"]],  # tokenized references for the first sample (2 references)
    [["foo", "bar", "foobar"]]                                           # tokenized references for the second sample (1 reference)
    ]
    
defaultnya max_order yang digunakan = 4 (n-gram 4)
semakin banyak max order maka nilai BLEU cenderung makin kecil karena urutan harus sama sebanyak n-gram
'''

def hitung_bleu_score(predictions, references):
    results = bleu.compute(predictions=predictions, references=references, max_order=1) 
    return results

# %% [markdown]
# ## Modul untuk menghitung Word Error Rate

# %%
from jiwer import wer

def hitung_wer(reference, prediksi):
    wer_ = wer(reference, prediksi)
    return wer_

# %% [markdown]
# ### pencarian rules dan transformasi

# %%
rules = [
            (['NNP','VB','NNP'], 2, 'dari'),                 #1
            (['CC','NN','NN'], 2, 'sejak'),                  #2
            (['NN','NN','NN'], 1, 'sejak'),                  #3
            (['NN','VB','NN'], 2, 'di'),                     #4
#             (['NN','VB','NN'], 2, 'dalam'),                #5
            (['IN','NN','NN'], 2, 'pada'),                   #6
            (['PRP','NEG','JJ'], 0, 'bagi'),                 #7
#             (['MD','VB','NN'], 2, 'dengan'),               #8
            (['PR','VB','NN'], 2, 'atas'),                   #9
            (['NN','NN','RB'], 1, 'terhadap'),               #10
            (['VB','NN','NN'], 2, 'tentang'),                #11
            (['VB','NN','PRP'], 2, 'untuk'),                 #12
            (['NN','JJ','NN'], 2, 'oleh'),                   #13
            (['PRP','VB','NNP'], 2, 'ke'),                   #14
            (['PR','NN','NN'], 2, 'seperti'),                #15
            (['MD','VB','NN'], 2, 'akan'),                   #16        
            (['NN','NNP','CC'], 1, 'antara'),                #17
            (['VB','JJ','NN'], 2, 'demi'),                   #18
            (['NN','JJ','OD'], 1, 'hingga'),                 #19
            (['VB','Z','NN'], 2, 'kecuali'),                 #20    
            (['NN','CD','NN'], 2, 'sampai'),                 #21    
            (['NN','NND','SYM'], 1, 'per'),                  #22     
            (['VB','NN','NN'], 1, 'tanpa'),                  #23     
            (['VB','NN','SC'], 1, 'menjelang'),              #24     
            (['NNP','JJ','NN'], 2, 'bagaikan'),              #25     
]

# %%
## manipulasi tuple
def modify(pos_seq, word_seq, rules, word_seq_join):
    tokenized_word_seq = word_seq_join.split()
    cnt = 0
    for i in range(len(pos_seq)):
        curr_pos = list(pos_seq[i])
        curr_word = list(word_seq[i])
        for j in range(len(rules)):
            rule = rules[j][0]
            index = rules[j][1]
            kata = rules [j][2]
            
            if (curr_pos == rule):
#                 print("trigram index ke : " + str(i) + " : rule ke " + str(j))
#                 print(str(index) + " " + kata)
                cnt += index
                tokenized_word_seq.insert(cnt, kata)
#                 print(tokenized_word_seq)
#                 print("======================")
        cnt += 1
    return tokenized_word_seq

# %% [markdown]
# ## Testing/Prediksi Kalimat Akhir

# %%
list_all_pred = []
list_all_ref = []
list_pred_kal = []
list_ref_kal = []

# %%
# prepare testing data
def clean(source_file):  
    root_dir = f'/workspace/BISINDO/Translation/Huda/'
    f = open(f'{root_dir}/{source_file}', 'r')
    k = open(f'{root_dir}/[bindo2]-bindo368.txt', 'r')
    output_txt = open(f'{root_dir}/[processed]-{source_file}', 'w')    
#     output_csv = open(f'{root_dir}/[csv]-{source_file}.csv', 'w')

    for i in range(367):
#     for kal in f:
        kal_pred = f.readline()
        kal_ref = k.readline()
        
        pos_seq, word_seq = extract_word_tag(kal_pred)
        pos_seq_join = (' ').join(pos_seq)
        word_seq_join = (' ').join(word_seq)
        

        trigram_word_seq = ngram(word_seq_join, 3)
        trigram_pos_seq = ngram(pos_seq_join, 3)
        
        prediksi = modify(trigram_pos_seq, trigram_word_seq, rules, word_seq_join)
        
        print("kalimat prediksi: ", (' ').join(prediksi))
        print("kalimat referensi: ", kal_ref)
        print(pos_seq_join)
        
        list_ref = kal_ref.split()
        list_all_pred.append(prediksi)
        list_all_ref.append([kal_ref.split()])
        list_pred_kal.append((' ').join(prediksi))
        list_ref_kal.append(kal_ref)
        
#         bleu_individual = hitung_bleu_score([prediksi],[[list_ref]])
#         bleu_score_individual = bleu_individual['bleu']*100
        wer_individual = hitung_wer([kal_ref], [(' ').join(prediksi)])
        print("WER individual: ", wer_individual)
#         print("BLEU Score Per Kalimat :", float("{:.2f}".format(bleu_score_individual)))
        print("----------------------------------")
        
#         print(trigram_word_seq)
#         print(trigram_pos_seq)
#         is_modified, modified_word, applied_rules = transform(pos_seq, word_seq, rules)
#         prediksi = ' '.join(modified_word)
        
#         output_txt.write(f'{prediksi}\t{kal}')
#         output_csv.write(f'{kal_normed},{prediksi},{is_modified},{applied_rules}\n')
    
#     output_csv.close()
    bleu_score = hitung_bleu_score(list_all_pred,list_all_ref)
    wer_ = hitung_wer(list_ref_kal, list_pred_kal)
    print("BLEU Score Keseluruhan: ",bleu_score['bleu']*100)
    print("WER: ", wer_)
    output_txt.close()
    f.close()

# %%
# menambahkan preposisi pada kelimat bahasa indonesia setengah jadi
files_to_be_translated = [
    '[test]-[bindo2]-bindo368.txt'
]

for el in files_to_be_translated:
    print(f'Processing {el}...')
    clean(el)
    print('=======')
# Out:
# Processing [test]-[bindo2]-bindo368.txt...
# kalimat prediksi:  nanti saya nonton bioskop
# kalimat referensi:  nanti saya akan nonton ke bioskop
#
# NN PRP VB NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  besok pagi saya belanja pasar
# kalimat referensi:  besok pagi saya akan belanja ke pasar
#
# NN NN PRP NN NN
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  tidak boleh bicara akan sekarang
# kalimat referensi:  serta tidak boleh bicara sekarang
#
# NEG MD VB NN
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  warga tidak boleh mudik akan akhir tahun tentang tanpa
# kalimat referensi:  warga tidak boleh mudik akhir tahun
#
# NN NEG MD VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  tiap hari ayah olahraga lama 1 jam
# kalimat referensi:  tiap hari ayah olahraga lama 1 jam
#
# CD NN NN VB JJ CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  tiap siang saya tidur lama 1 jam
# kalimat referensi:  tiap siang saya tidur lama 1 jam
#
# CD NN PRP VB JJ CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kalau berani saya berangkat
# kalimat referensi:  kalau berani saya berangkat
#
# SC JJ PRP VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  walaupun sedih saya kerja
# kalimat referensi:  walaupun sedih saya kerja
#
# SC JJ PRP VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  adik saya biasa berangkat jam 7 sampai pagi
# kalimat referensi:  adik saya biasa berangkat jam 7 pagi
#
# NN PRP RB VB NN CD NN
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  rani seringkali mandi pukul 6 sampai pagi
# kalimat referensi:  rani seringkali mandi pukul 6 pagi
#
# NNP RB VB NN CD NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  biarpun gagal saya senyum
# kalimat referensi:  biarpun gagal saya senyum
#
# SC VB PRP JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  walaupun kecewa saya tertawa
# kalimat referensi:  walaupun kecewa saya tertawa
#
# SC JJ PRP VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  anak sejak laki laki itu senang karena ibu masak
# kalimat referensi:  anak laki laki itu senang karena ibu masak
#
# NN NN NN PR JJ SC NN VB
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  saya senang karena saya rasa puji di ayah
# kalimat referensi:  saya senang karena saya rasa puji oleh ayah
#
# PRP JJ SC PRP NN VB NN
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  adik sedih karena adik rasa ejek teman
# kalimat referensi:  adik sedih karena adik rasa ejek oleh teman
#
# NN JJ SC NN VB VB NN
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  jangan cemas ayah harus kamu
# kalimat referensi:  jangan cemas ayah harus antar kamu
#
# NEG JJ NN MD PRP
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  pasien bingung mengapa pasien tidak boleh makan akan daging
# kalimat referensi:  pasien bingung mengapa pasien tidak boleh makan daging
#
# NN JJ WH NN NEG MD VB NN
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  tiap sore kakak saya main badminton dan lari sejak jarak sejak pendek
# kalimat referensi:  tiap sore kakak saya main badminton dan lari jarak pendek
#
# CD NN NN PRP VB NN CC NN NN NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  sarah pinjam uang itu gadai
# kalimat referensi:  sarah pinjam uang itu dari gadai
#
# NNP VB NN PR NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  kakak pinjam di buku baca
# kalimat referensi:  kakak akan pinjam buku baca
#
# NN VB NN VB
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  ayah saya beli saya motor
# kalimat referensi:  ayah saya beli saya motor
#
# NN PRP VB PRP NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apakah dia belum ambil paket menteri budiono ?
# kalimat referensi:  apakah dia belum ambil paket dari menteri budiono ?
#
# SC PRP NEG VB NN NNP NNP Z
# WER individual:  0.1111111111111111
# ----------------------------------
# kalimat prediksi:  kamu tidak paham nyata saya
# kalimat referensi:  kamu tidak paham nyata saya
#
# PRP NEG VB JJ PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  lagu itu sudah dengar juta
# kalimat referensi:  lagu itu sudah dengar oleh juta guna
#
# NN PR MD VB CD
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  apakah kamu pernah tonton akan film bahasa jawa ?
# kalimat referensi:  apakah kamu pernah tonton film bahasa jawa ?
#
# WH PRP MD VB NN NNP NNP Z
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  rumah ini sewa seperti ayah sejak biaya dua juta
# kalimat referensi:  rumah ini sewa oleh ayah dengan biaya dua juta
#
# NN PR NN NN NN CD CD
# WER individual:  0.2222222222222222
# ----------------------------------
# kalimat prediksi:  siswa itu puji atas guru
# kalimat referensi:  siswa itu puji oleh guru
#
# NN PR VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  saya marah bapak
# kalimat referensi:  saya marah oleh bapak
#
# PRP JJ NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  kucing itu kejar atas anjing
# kalimat referensi:  kucing itu kejar anjing
#
# NN PR VB NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  adik dicerahami di ibu
# kalimat referensi:  adik dicerahami ibu
#
# NN VB NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  masker ini baik tiga kali minggu
# kalimat referensi:  masker ini baik guna tiga kali minggu
#
# NN PR JJ CD NN NN
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  tugas tanya saya mana saya sekolah
# kalimat referensi:  tugas tanya saya di mana saya sekolah
#
# NN VB PRP SC PRP VB
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  ibu tanya saya mana saya belanja
# kalimat referensi:  ibu tanya saya ke mana saya belanja
#
# NN VB PRP SC PRP VB
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  apa kamu lamun ?
# kalimat referensi:  apa kamu lamun ?
#
# WH PRP X Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  mana adik lari ?
# kalimat referensi:  ke mana adik lari ?
#
# WH NN VB Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  mana kakak sekolah ?
# kalimat referensi:  di mana kakak akan sekolah ?
#
# WH NN VB Z
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kenapa besok kamu tidak sekolah ?
# kalimat referensi:  kenapa besok kamu tidak sekolah ?
#
# SC NN PRP NEG VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  bagaimana kondisi ayah ?
# kalimat referensi:  bagaimana kondisi ayah ?
#
# WH NN NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  bagaimana sehat adik ?
# kalimat referensi:  bagaimana sehat adik ?
#
# WH JJ NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  jam berapa kamu berangkat ?
# kalimat referensi:  jam berapa kamu berangkat ?
#
# NN WH PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  buku apa kamu pinjam ?
# kalimat referensi:  buku apa kamu pinjam ?
#
# NN WH PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kapan bapak beli di sepeda ?
# kalimat referensi:  kapan bapak beli sepeda ?
#
# WH NN VB NN Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  sepatu saya kecil sepatu adik saya besar
# kalimat referensi:  sepatu saya kecil sepatu adik saya besar
#
# NN PRP JJ NN NN PRP JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  batik bal itu bagus tetapi mahal
# kalimat referensi:  batik bal itu bagus tetapi mahal
#
# NN NN PR JJ CC JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  gambar kurang jelas tidak dapat saya lihat
# kalimat referensi:  gambar kurang jelas tidak dapat saya lihat
#
# NN RB JJ NEG MD PRP VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  ratna suka makan asin dina suka makan manis
# kalimat referensi:  ratna suka makan asin dina suka makan manis
#
# NNP VB VB JJ NNP RB VB JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  tolong nyala tv untuk nya
# kalimat referensi:  tolong nyala tv nya
#
# RB VB NN PRP
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  jangan teriak depan tentang tanpa kelas
# kalimat referensi:  jangan teriak di depan kelas
#
# NEG VB NN NN
# WER individual:  0.6
# ----------------------------------
# kalimat prediksi:  rampok itu tendang saya kali kali
# kalimat referensi:  rampok itu tendang saya kali kali
#
# NN PR VB PRP NN NND
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  dia anak nakal banyak orang benci
# kalimat referensi:  dia anak nakal banyak orang benci
#
# PRP NN JJ CD NN VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  dia masih ingat akan tragedi renggut dua orang tua 10 tahun sampai lalu
# kalimat referensi:  dia masih ingat akan tragedi renggut dua orang tua 10 tahun lalu
#
# PRP MD VB NN VB CD NN NN CD NN CC
# WER individual:  0.08333333333333333
# ----------------------------------
# kalimat prediksi:  aku tidak pernah bisa lupa akan budi baik tentang tanpa keluarga sejak kami
# kalimat referensi:  aku tidak akan pernah bisa lupa akan budi baik pada keluarga kami
#
# PRP NEG MD MD VB NN NN NN PRP
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  bagai atur itu izin
# kalimat referensi:  bagai atur itu buat atas izin
#
# IN VB PR NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  saya turut duka tentang tanpa cita tinggal orang di tua tentang tanpa
# kalimat referensi:  saya turut duka cita atas tinggal orang tua
#
# PRP VB NN NN VB NN NN
# WER individual:  0.75
# ----------------------------------
# kalimat prediksi:  rumah dan sekolah hanya tempuh 10 menit
# kalimat referensi:  antara rumah dan sekolah hanya tempuh 10 menit
#
# NN CC NN RB VB CD NN
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  peperangan antara palestina dan israel tidak pernah akhir
# kalimat referensi:  peperangan antara palestina dan israel tidak pernah akhir
#
# NN NNP CC NNP NEG MD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  gadis kecil jual goreng itu selalu lintas jalan ini pukul 3 sampai pukul 5 sore sampai
# kalimat referensi:  gadis kecil jual goreng itu selalu lintas di jalan ini antara pukul 3 sampai pukul 5 sore
#
# NN JJ VB NN PR RB VB NN PR NN CD NN CD NN
# WER individual:  0.17647058823529413
# ----------------------------------
# kalimat prediksi:  bagi saya tidak penting dia ikut atau tidak
# kalimat referensi:  bagi saya tidak penting dia ikut atau tidak
#
# PRP NEG JJ PRP VB CC NEG
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  merdeka negara republik indonesia dapat raih berkat juang pahlawan
# kalimat referensi:  merdeka negara republik indonesia dapat raih berkat juang pahlawan
#
# JJ NN NNP NNP MD VB IN JJ NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  tari pendet asal bali
# kalimat referensi:  tari pendet asal dari bali
#
# NN NN IN NNP
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  bis kota berangkat di terminal
# kalimat referensi:  bis kota berangkat dari terminal
#
# NN NN VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  air sejak mata tetes dua sampai mata
# kalimat referensi:  air mata tetes dari dua mata
#
# NN NN NN CD NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  rumah saya berangkat jam 10 00
# kalimat referensi:  dari rumah saya berangkat jam 10 00
#
# NN PRP VB NN CD CD
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  kerja sejak tugas halaman 11 sampai halaman 13
# kalimat referensi:  kerja tugas dari halaman 11 sampai halaman 13
#
# NN NN NN CD NN CD
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  kita mulai kerja tentang tanpa bakti sejak ujung sejak jalan ini
# kalimat referensi:  kita mulai kerja bakti dari ujung jalan ini
#
# PRP VB NN NN NN NN PR
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  sini kantor terhadap pos kira kira 1 kilometer
# kalimat referensi:  dari sini ke kantor pos kira kira 1 kilometer
#
# X NN NN RB RB CD NND
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  larang pindah buku tentang tanpa buku sejak tempat
# kalimat referensi:  larang pindah buku buku dari tempat
#
# VB VB NN NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  saya baru pulang akan sekolah
# kalimat referensi:  saya baru pulang dari sekolah
#
# PRP MD VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  stasiun mana kereta sejak api bisnis berangkat ?
# kalimat referensi:  dari stasiun mana kereta api bisnis berangkat ?
#
# NN WH NN NN NN VB Z
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  kami kerja keras sejahtera keluarga
# kalimat referensi:  kami akan kerja keras demi sejahtera keluarga
#
# PRP NN JJ JJ NN
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  penting bangun kami rela korban
# kalimat referensi:  demi penting bangun kami rela korban
#
# JJ VB PRP VB NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  saya juang benar dan adil
# kalimat referensi:  saya juang demi benar dan adil
#
# PRP VB JJ CC JJ
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  angkat batu itu satu satu
# kalimat referensi:  angkat batu itu satu demi satu
#
# VB NN PR CD CD
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  kertas itu bakar atas lembar lembar tentang tanpa
# kalimat referensi:  kertas itu bakar lembar demi lembar
#
# NN PR VB NN NN
# WER individual:  0.6666666666666666
# ----------------------------------
# kalimat prediksi:  alloh saya tidak pernah ambil akan buku
# kalimat referensi:  demi alloh saya tidak pernah ambil buku
#
# NNP PRP NEG MD VB NN
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  tuhan saya tidak tahu nahu urus itu
# kalimat referensi:  demi tuhan saya tidak tahu nahu dengan urus itu
#
# NNP PRP NEG VB NNP VB PR
# WER individual:  0.2222222222222222
# ----------------------------------
# kalimat prediksi:  kuasa alam segenap sampai isi saya sumpah tetap tinggal sini
# kalimat referensi:  demi kuasa alam dengan segenap isi saya sumpah akan tetap tinggal sini
#
# NN NN CD NN PRP NN RB VB VB
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  hasil uji nasional oleh tahun ini 100 periksa komputer
# kalimat referensi:  hasil uji nasional tahun ini 100 akan periksa dengan komputer
#
# NN NN JJ NN PR CD VB NN
# WER individual:  0.3
# ----------------------------------
# kalimat prediksi:  rumah tua itu jual lengkap segala isi
# kalimat referensi:  rumah tua itu jual lengkap dengan segala isi
#
# NN JJ PR VB JJ CD NN
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  kami terima sumbang itu senang hati
# kalimat referensi:  kami terima sumbang itu dengan senang hati
#
# PRP VB VB PR JJ JJ
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  nama allah rahmat sejak tuhan sejak restu sejak orang tua
# kalimat referensi:  dengan nama allah dengan rahmat tuhan dengan restu orang tua
#
# NN NNP NN NN NN NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  pak andi kerja dari bandung
# kalimat referensi:  pak andi kerja di bandung
#
# NNP NNP VB NNP
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  tanding sepakbola selenggara di stadion
# kalimat referensi:  tanding sepakbola selenggara di stadion
#
# VB NN VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  larang bicara keras keras pustaka
# kalimat referensi:  larang bicara keras keras di pustaka
#
# VB VB JJ JJ NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  pasar banyak sampai orang jual
# kalimat referensi:  di pasar banyak orang jual
#
# NN CD NN VB
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  sini semua sampai anak harus sikap sopan
# kalimat referensi:  di sini semua anak harus sikap sopan
#
# NN CD NN MD NN JJ
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  kerja sejak soal sejak soal sejak buku sejak matematika halaman 23
# kalimat referensi:  kerja soal soal di buku matematika halaman 23
#
# NN NN NN NN NN NN CD
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  bu guru tulis di papan tulis tentang tanpa
# kalimat referensi:  bu guru tulis di papan tulis
#
# NN NN VB NN NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  foto foto baik simpan album tentang tanpa foto
# kalimat referensi:  foto foto baik simpan di album foto
#
# NN NN JJ VB NN NN
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  negara mana dapat menara eiffel ?
# kalimat referensi:  di negara mana dapat menara eiffel ?
#
# NN WH VB NN NNP Z
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  rumah siapa kita kumpul nanti ?
# kalimat referensi:  di rumah siapa kita kumpul nanti ?
#
# NN WH PRP VB NN Z
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  seragam sejak sekolah adik simpan di lemari
# kalimat referensi:  seragam sekolah adik simpan dalam lemari
#
# NN NN NN VB NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  bencana sejak banjir bandang jadi di bulan lalu 40 orang nyata hilang
# kalimat referensi:  dalam bencana banjir bandang jadi bulan lalu 40 orang nyata hilang
#
# NN NN NN VB NN CC CD NN JJ VB
# WER individual:  0.2727272727272727
# ----------------------------------
# kalimat prediksi:  kurun terhadap waktu kurang 5 menit sejak tiket konser salah satu band sejak nama sejak tanah air itu telah habis jual
# kalimat referensi:  dalam kurun waktu kurang dari 5 menit tiket konser salah satu band nama tanah air itu telah habis jual
#
# NN NN RB CD NN NN NN CD CD NN NN NN NN PR MD VB VB
# WER individual:  0.3157894736842105
# ----------------------------------
# kalimat prediksi:  ia menang panjang demi malam bengkak dua mata
# kalimat referensi:  ia menang panjang malam hingga bengkak dua mata
#
# PRP VB JJ NN JJ CD NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  jelang tahun baru kita baharu tekad maju
# kalimat referensi:  jelang tahun baru kita baharu tekad untuk maju
#
# IN NNP NNP PRP JJ NN VB
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  dadang pulang kampung tasikmalaya
# kalimat referensi:  dadang pulang kampung ke tasikmalaya
#
# NNP VB VB NNP
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  saya pergi sekolah tentang tanpa sepeda
# kalimat referensi:  saya pergi ke sekolah dengan sepeda
#
# PRP VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  tumpang silah naik pesawat
# kalimat referensi:  tumpang silah naik ke pesawat
#
# VB VB VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  ia berangkat kantor tentang tanpa bis sejak kota
# kalimat referensi:  ia berangkat ke kantor guna bis kota
#
# PRP VB NN NN NN
# WER individual:  0.5714285714285714
# ----------------------------------
# kalimat prediksi:  jantung pompa di darah seluruh tubuh sampai
# kalimat referensi:  jantung pompa darah ke seluruh tubuh
#
# NN VB NN CD NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  jahat itu bawa atas kantor polisi tentang tanpa
# kalimat referensi:  jahat itu bawa ke kantor polisi
#
# JJ PR VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  kita bisa unggah akan foto internet tentang tanpa
# kalimat referensi:  kita bisa unggah foto ke internet
#
# PRP MD VB NN NN
# WER individual:  0.6666666666666666
# ----------------------------------
# kalimat prediksi:  garis lurus oleh titik a titik b
# kalimat referensi:  buat garis lurus dari titik a ke titik b
#
# NN JJ NN NNP NN NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  berang terhadap berang biasa selam dasar tentang tanpa sungai
# kalimat referensi:  berang berang biasa selam sampai ke dasar sungai
#
# NN NN RB VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  rumah siapa kamu pergi saat lebaran ?
# kalimat referensi:  ke rumah siapa kamu pergi saat lebaran ?
#
# NN WH PRP VB NN NNP Z
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  tidak ada hirau keluarga tentang tanpa sendiri
# kalimat referensi:  tidak ada hirau kecuali keluarga sendiri
#
# NEG VB VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  tenaga masih kurang angkat beban
# kalimat referensi:  tenaga masih kurang untuk angkat beban
#
# NN MD RB VB NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  tahan itu sudah tangkap kembali
# kalimat referensi:  tahan lepas itu sudah tangkap kembali
#
# VB PR MD VB VB
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  negara itu sudah cengkeram jajah
# kalimat referensi:  negara itu sudah lepas dari cengkeram jajah
#
# NN PR MD VB VB
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  kereta api cepat jakarta surabaya semarang
# kalimat referensi:  kereta api cepat jakarta surabaya lewat semarang
#
# NN NN JJ NNP NNP NNP
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  jembatan hubung dua sampai kabupaten itu dulunya resmi presiden sby
# kalimat referensi:  jembatan hubung dua kabupaten itu dulunya resmi oleh presiden sby
#
# NN NN CD NN PR RB JJ NNP NNP
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  kemeja basah oleh keringat
# kalimat referensi:  kemeja basah oleh keringat
#
# NN JJ NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  ibu guru suruh kami kerja soal tentang tanpa halam 90 halaman sampai 102
# kalimat referensi:  ibu guru suruh kami kerja soal dari halam 90 sampai halaman 102
#
# NN NN VB PRP VB NN NN CD NN CD
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kini sejak teknologi komunikasi dapat tembus akan batas ruang tentang tanpa dan waktu ada internet di
# kalimat referensi:  kini teknologi komunikasi dapat tembus batas ruang dan waktu sejak ada internet
#
# NN NN NN MD VB NN NN CC NN VB NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  kue itu bentuk seperti martabak
# kalimat referensi:  kue itu bentuk seperti martabak
#
# NN PR NN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  segala gala sejak laku sejak perintah tuan
# kalimat referensi:  segala gala laku seperti perintah tuan
#
# CD NN NN NN NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  ayah beri jelas demi materi ajar tidak saya paham
# kalimat referensi:  ayah beri jelas tentang materi ajar tidak saya paham
#
# NN VB JJ NN VB NEG PRP VB
# WER individual:  0.1111111111111111
# ----------------------------------
# kalimat prediksi:  esok hari mereka tuju ke bandung
# kalimat referensi:  esok hari mereka tuju ke bandung
#
# NN NN PRP VB NNP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  turut berita tentang tanpa radio sejak pagi ini presiden tinjau daerah tani sulawesi
# kalimat referensi:  turut berita radio pagi ini presiden akan tinjau daerah tani di sulawesi
#
# VB NN NN NN PR NNP VB NN JJ NNP
# WER individual:  0.4166666666666667
# ----------------------------------
# kalimat prediksi:  tindak hadap di musuh kejam
# kalimat referensi:  tindak hadap musuh kejam
#
# NN VB NN JJ
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  beliau bawa kami
# kalimat referensi:  beliau bawa oleh oleh untuk kami
#
# PRP VB PRP
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  pupuk kirim di tani
# kalimat referensi:  pupuk kirim untuk tani
#
# NN VB NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  ayah beli di sepatu ibu tentang tanpa
# kalimat referensi:  ayah beli sepatu untuk ibu
#
# NN VB NN NN
# WER individual:  0.8
# ----------------------------------
# kalimat prediksi:  penting umum
# kalimat referensi:  untuk penting umum
#
# JJ JJ
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kami rela korban
# kalimat referensi:  kami rela korban
#
# PRP VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  uang tidak ada arti
# kalimat referensi:  uang tidak ada arti
#
# NN NEG VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  hadiah dua juta rupiah sedia di karang baik
# kalimat referensi:  hadiah dua juta rupiah sedia untuk karang baik
#
# NN CD CD NN VB NN JJ
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  rusa lari cepat
# kalimat referensi:  rusa lari cepat
#
# NN VB JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  badak lebih besar daripada singa
# kalimat referensi:  badak lebih besar daripada singa
#
# NN RB JJ IN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kenapa kamu tidak suka harimau ?
# kalimat referensi:  kenapa kamu tidak suka harimau ?
#
# WH PRP NEG VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  harimau itu buas
# kalimat referensi:  harimau itu buas
#
# NN PR JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  harimau dan singa sama cepat
# kalimat referensi:  harimau dan singa sama cepat
#
# NN CC NN JJ JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  mana kelelawar gelayut ?
# kalimat referensi:  di mana kelelawar gelayut ?
#
# WH NN VB Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  kelelawar gelayut di pohon atau gua
# kalimat referensi:  kelelawar gelayut di pohon atau gua
#
# NN VB NN CC NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apa binatang paling kuat ?
# kalimat referensi:  apa binatang paling kuat ?
#
# WH NN RB JJ Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  gajah paling kuat
# kalimat referensi:  gajah paling kuat
#
# NN RB JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  binatang apa tinggal gua ?
# kalimat referensi:  binatang apa tinggal di gua ?
#
# NN WH VB NN Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  harimau singa dan kelinci tinggal di gua
# kalimat referensi:  harimau singa dan kelinci tinggal di gua
#
# NN NN CC NN VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  landak masuk di gua
# kalimat referensi:  landak masuk ke dalam gua
#
# NN VB NN
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  buaya bisa hidup mana ?
# kalimat referensi:  buaya bisa hidup di mana ?
#
# NN MD NN SC Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  buaya bisa hidup akan sungai dan tanah
# kalimat referensi:  buaya bisa hidup di sungai dan tanah
#
# NN MD VB NN CC NN
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  saya tidak suka uang tentang tanpa koin
# kalimat referensi:  saya tidak suka uang koin
#
# PRP NEG VB NN NN
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  apakah kamu punya uang ?
# kalimat referensi:  apakah kamu punya uang ?
#
# WH PRP VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak punya uang
# kalimat referensi:  saya tidak punya uang
#
# PRP NEG VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kamu punya uang berapa ?
# kalimat referensi:  kamu punya uang berapa ?
#
# PRP VB NN WH Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak punya uang
# kalimat referensi:  saya tidak punya uang
#
# PRP NEG VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  berapa harga sejak baju merah ?
# kalimat referensi:  berapa harga baju merah ?
#
# WH NN NN NN Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  saya bisa bantu tawar
# kalimat referensi:  saya bisa bantu untuk tawar
#
# PRP MD VB VB
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  tidak bisa tawar
# kalimat referensi:  tidak bisa tawar
#
# NEG MD VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  uang bagi saya tidak cukup
# kalimat referensi:  uang saya tidak cukup
#
# NN PRP NEG JJ
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  kira kira kamu mau berapa ?
# kalimat referensi:  kira kira kamu mau berapa ?
#
# RB RB PRP MD CD Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kemarin saya beli 4 apel
# kalimat referensi:  kemarin saya beli 4 apel
#
# NN PRP VB CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kamu bisa tawar
# kalimat referensi:  kamu bisa tawar
#
# PRP MD VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apa kerja kamu sekarang ?
# kalimat referensi:  apa kerja kamu sekarang ?
#
# WH NN PRP NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya karyawan kantor
# kalimat referensi:  saya karyawan kantor
#
# PRP NN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kerja apa kamu suka ?
# kalimat referensi:  kerja apa kamu suka ?
#
# NN WH PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya suka jahit
# kalimat referensi:  saya suka jahit
#
# PRP VB VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  mengapa kamu suka gunting rambut ?
# kalimat referensi:  mengapa kamu suka gunting rambut ?
#
# WH PRP VB VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  mengapa kamu suka gunting rambut ?
# kalimat referensi:  mengapa kamu suka gunting rambut ?
#
# WH PRP VB VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya punya ahli gunting di rambut
# kalimat referensi:  saya punya ahli gunting rambut
#
# PRP VB NN VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  jam berapa kamu mulai kerja ?
# kalimat referensi:  jam berapa kamu mulai kerja ?
#
# NN WH PRP VB VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya mulai kerja tentang tanpa jam 8 pagi sampai
# kalimat referensi:  saya mulai kerja pada jam 8 pagi
#
# PRP VB NN NN CD NN
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  ibu kamu kerja apa ?
# kalimat referensi:  ibu kamu kerja apa ?
#
# NN PRP VB WH Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  ibu saya ibu sejak rumah tangga
# kalimat referensi:  ibu saya ibu rumah tangga
#
# NN PRP NN NN NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  kamu karyawan pabrik apa ?
# kalimat referensi:  kamu karyawan pabrik apa ?
#
# PRP NN NN WH Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya karyawan sejak pabrik jahit
# kalimat referensi:  saya karyawan pabrik jahit
#
# PRP NN NN NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  berapa jam kamu kerja satu hari ?
# kalimat referensi:  berapa jam kamu kerja dalam satu hari ?
#
# WH NN PRP VB CD NN Z
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  saya kerja lama delapan jam
# kalimat referensi:  saya kerja lama delapan jam
#
# PRP NN JJ CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  berapa gaji satu sampai bulan karyawan ?
# kalimat referensi:  berapa gaji satu bulan karyawan ?
#
# WH NN CD NN NN Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  gaji satu sampai bulan satu juta
# kalimat referensi:  gaji satu bulan satu juta
#
# NN CD NN CD CD
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  tukang sejak kayu kerja mana ?
# kalimat referensi:  tukang kayu kerja di mana ?
#
# NN NN NN WH Z
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  tukang sejak kayu sejak kerja rumah atau bangun
# kalimat referensi:  tukang kayu kerja di rumah atau bangun
#
# NN NN NN NN CC VB
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  kerja sejak tukang masak berat atau ringan ?
# kalimat referensi:  kerja tukang masak berat atau ringan ?
#
# NN NN NN JJ CC JJ Z
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  apa kerja bapak kamu ?
# kalimat referensi:  apa kerja bapak kamu ?
#
# WH NN NN PRP Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  bapak kerja di acara
# kalimat referensi:  bapak kerja acara
#
# NN VB NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kamu kerja awat lama berapa tahun ?
# kalimat referensi:  kamu kerja awat lama berapa tahun ?
#
# PRP NN X JJ WH NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kamu kerja awat sudah berapa lama ?
# kalimat referensi:  kamu kerja awat sudah berapa lama ?
#
# PRP NN X MD WH JJ Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya sudah kerja awat lama satu tahun
# kalimat referensi:  saya sudah kerja awat lama satu tahun
#
# PRP MD NN X JJ CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kapan kamu jadi dokter ?
# kalimat referensi:  kapan kamu jadi dokter ?
#
# WH PRP VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya jadi dokter tentang tanpa tahun 1994
# kalimat referensi:  saya jadi dokter pada tahun 1994
#
# PRP VB NN NN CD
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kamu kerja rumah tentang tanpa sakit apa ?
# kalimat referensi:  kamu kerja di rumah sakit apa ?
#
# PRP VB NN NN WH Z
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  saya kerja ke rumah sakit asih
# kalimat referensi:  saya kerja di rumah sakit asih
#
# PRP VB NNP NNP NNP
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  bagaimana cara kamu pergi pabrik ?
# kalimat referensi:  bagaimana cara kamu pergi ke pabrik ?
#
# WH NN PRP VB NN Z
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  saya pergi pabrik tentang tanpa bus sejak usaha
# kalimat referensi:  saya pergi ke pabrik dengan bus usaha
#
# PRP VB NN NN NN
# WER individual:  0.5714285714285714
# ----------------------------------
# kalimat prediksi:  apakah kamu tahu cara luk ?
# kalimat referensi:  apakah kamu tahu cara luk ?
#
# WH PRP VB NN NNP Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak tahu cara tentang tanpa luk
# kalimat referensi:  saya tidak tahu cara luk
#
# PRP NEG VB NN NN
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  apa kerja kamu impi ?
# kalimat referensi:  apa kerja kamu impi ?
#
# WH NN PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya mimpi jadi di aktor
# kalimat referensi:  saya mimpi jadi aktor
#
# PRP NN VB NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  apakah nyanyi itu kenal ?
# kalimat referensi:  apakah nyanyi itu kenal ?
#
# WH VB PR VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  nyanyi itu kenal
# kalimat referensi:  nyanyi itu kenal
#
# VB PR VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  baju apa kamu pakai hari tentang tanpa ini ?
# kalimat referensi:  baju apa kamu pakai hari ini ?
#
# NN WH PRP VB NN NN Z
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  hari ini saya pakai baju tentang tanpa kaus
# kalimat referensi:  hari ini saya pakai baju kaus
#
# NN PR PRP VB NN NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kamu sering kerja pakai di celana apa ?
# kalimat referensi:  kamu sering kerja pakai celana apa ?
#
# PRP RB NN VB NN WH Z
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  saya sering pakai jeans
# kalimat referensi:  saya sering pakai jeans
#
# PRP RB VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  pakai apa jarang kamu pakai ?
# kalimat referensi:  pakai apa jarang kamu pakai ?
#
# VB WH RB PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya jarang pakai baju tentang tanpa koko
# kalimat referensi:  saya jarang pakai baju koko
#
# PRP RB VB NN NN
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  apakah benar kemarin kamu pakai gaun ?
# kalimat referensi:  apakah benar kemarin kamu pakai gaun ?
#
# SC JJ NN PRP VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya pakai baju tentang tanpa kerah dan rok
# kalimat referensi:  saya pakai baju kerah dan rok
#
# PRP VB NN NN CC NN
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kamu sering pakai baju apa musim panas ?
# kalimat referensi:  kamu sering pakai baju apa pada musim panas ?
#
# PRP RB VB NN WH NN NN Z
# WER individual:  0.1111111111111111
# ----------------------------------
# kalimat prediksi:  saya sering pakai baju tentang tanpa kaus sejak musim sejak panas
# kalimat referensi:  saya sering pakai baju kaus pada musim panas
#
# PRP RB VB NN NN NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  model baju apa tidak kamu suka ?
# kalimat referensi:  model baju apa tidak kamu suka ?
#
# NN NN WH NEG PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak suka baju tentang tanpa koko
# kalimat referensi:  saya tidak suka baju koko
#
# PRP NEG VB NN NN
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  berapa orang punya di baju kerah tentang tanpa lengan sejak panjang sejak ?
# kalimat referensi:  berapa orang punya baju kerah lengan panjang ?
#
# CD NN VB NN NN NN NN Z
# WER individual:  0.625
# ----------------------------------
# kalimat prediksi:  dua orang punya di baju kerah tentang tanpa lengan sejak panjang sejak
# kalimat referensi:  dua orang punya baju kerah lengan panjang
#
# CD NN VB NN NN NN NN
# WER individual:  0.7142857142857143
# ----------------------------------
# kalimat prediksi:  celana panjang itu warna apa ?
# kalimat referensi:  celana panjang itu warna apa ?
#
# NN JJ PR NN WH Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  celana panjang itu warna hijau gelap
# kalimat referensi:  celana panjang itu warna hijau gelap
#
# NN JJ PR NN JJ JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  coba pakai baju untuk kamu beli
# kalimat referensi:  coba pakai baju kamu beli
#
# RB VB NN PRP VB
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  saya tidak tahu cara setrika di baju
# kalimat referensi:  saya tidak tahu cara setrika baju
#
# PRP NEG VB NN VB NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  apakah ada lampu tentang tanpa lalu sejak lintas sejak jalan itu ?
# kalimat referensi:  apakah ada lampu lalu lintas di jalan itu ?
#
# WH VB NN NN NN NN PR Z
# WER individual:  0.4444444444444444
# ----------------------------------
# kalimat prediksi:  jalan itu tidak ada lampu tentang tanpa lalu sejak lintas
# kalimat referensi:  jalan itu tidak ada lampu lalu lintas
#
# NN PR NEG VB NN NN NN
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  apakah ada jembatan jakarta bogor ?
# kalimat referensi:  apakah ada jembatan dari jakarta ke bogor ?
#
# WH VB NN NNP NNP Z
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  ada banyak jembatan
# kalimat referensi:  ada banyak jembatan
#
# VB CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  orang orang jalan kaki mana ?
# kalimat referensi:  orang orang jalan-kaki di mana ?
#
# NN NN VB VB SC Z
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  orang orang jalan di kaki trotoar tentang tanpa
# kalimat referensi:  orang orang jalan-kaki di trotoar
#
# NN NN VB NN NN
# WER individual:  0.8
# ----------------------------------
# kalimat prediksi:  saya selalu jalan kaki
# kalimat referensi:  saya selalu jalan kaki
#
# PRP RB VB VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kemarin jalan sudirman macet bagaikan jam 11 siang sampai
# kalimat referensi:  kemarin jalan sudirman macet dari jam 11 siang
#
# NN NN NNP JJ NN CD NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  daerah mana indonesia paling sering hujan ?
# kalimat referensi:  daerah mana di indonesia paling sering hujan ?
#
# NN WH NNP RB RB NN Z
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  hujan sering turun bogor
# kalimat referensi:  hujan sering turun di bogor
#
# NN RB VB NNP
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  bagaimana cuaca sejak musim panas ?
# kalimat referensi:  bagaimana cuaca pada musim panas ?
#
# WH NN NN NN Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  musim sejak panas cuaca panas
# kalimat referensi:  pada musim panas cuaca panas
#
# NN NN NN JJ
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  mana ada salju indonesia ?
# kalimat referensi:  di mana ada salju di indonesia ?
#
# WH VB NN NNP Z
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  papua indonesia timur
# kalimat referensi:  papua di indonesia bagi timur
#
# NNP NNP NNP
# WER individual:  0.4
# ----------------------------------
# kalimat prediksi:  apa warna awan ?
# kalimat referensi:  apa warna awan ?
#
# WH NN NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  awan warna hitam dan putih
# kalimat referensi:  awan warna hitam dan putih
#
# NN NN JJ CC JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kapan kamu lihat pelangi ?
# kalimat referensi:  kapan kamu lihat pelangi ?
#
# WH PRP VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  siapa takut petir ?
# kalimat referensi:  siapa takut petir ?
#
# SC JJ NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya takut petir
# kalimat referensi:  saya takut petir
#
# PRP JJ NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya paling takut gempa bumi
# kalimat referensi:  saya paling takut gempa bumi
#
# PRP RB JJ NN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apakah pernah baju kamu basah ketika hujan ?
# kalimat referensi:  apakah pernah baju kamu basah ketika hujan ?
#
# SC MD NN PRP JJ SC NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  baju saya pernah basah
# kalimat referensi:  baju saya pernah basah
#
# NN PRP MD JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apa bisa jadi ketika hujan ?
# kalimat referensi:  apa bisa jadi ketika hujan ?
#
# WH MD VB SC NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  ketika hujan kilat dan petir bisa jadi
# kalimat referensi:  ketika hujan kilat dan petir bisa jadi
#
# SC NN NN CC NN MD VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  mulut apa ?
# kalimat referensi:  mulut untuk apa ?
#
# NN WH Z
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  mulut kunyah dan makan
# kalimat referensi:  mulut untuk kunyah dan makan
#
# NN VB CC VB
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  telinga apa ?
# kalimat referensi:  telinga untuk apa ?
#
# NN WH Z
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  telinga dengar
# kalimat referensi:  telinga untuk dengar
#
# NN VB
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  apakah ular punya di telinga ?
# kalimat referensi:  apakah ular punya telinga ?
#
# WH NN VB NN Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  ular tidak punya telinga
# kalimat referensi:  ular tidak punya telinga
#
# NN NEG VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  binatang apa mata mirip di mata manusia tentang tanpa ?
# kalimat referensi:  binatang apa mata mirip dengan mata manusia ?
#
# NN WH NN VB NN NN Z
# WER individual:  0.375
# ----------------------------------
# kalimat prediksi:  mata manusia mirip di mata rusa tentang tanpa dan kucing
# kalimat referensi:  mata manusia mirip dengan mata rusa dan kucing
#
# NN NN VB NN NN CC NN
# WER individual:  0.375
# ----------------------------------
# kalimat prediksi:  binatang apa tidak punya telinga ?
# kalimat referensi:  binatang apa tidak punya telinga ?
#
# NN WH NEG VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  ular ikan dan buaya tidak punya telinga
# kalimat referensi:  ular ikan dan buaya tidak punya telinga
#
# NN NN CC NN RB VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  orang orang punya berapa gigi ?
# kalimat referensi:  orang orang punya berapa gigi ?
#
# NN NN VB CD NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  orang orang punya 32 gigi
# kalimat referensi:  orang orang punya 32 gigi
#
# NN NN VB CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apakah rambut bisa hitung ?
# kalimat referensi:  apakah rambut bisa hitung ?
#
# SC NN MD VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  rambut tidak bisa hitung
# kalimat referensi:  rambut tidak bisa hitung
#
# NN RB MD VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kamu suka alis apa ?
# kalimat referensi:  kamu suka alis seperti apa ?
#
# PRP VB NN WH Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  saya suka alis tebal
# kalimat referensi:  saya suka alis tebal
#
# PRP VB NN JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apakah kamu sekarang lapar ?
# kalimat referensi:  apakah kamu sekarang lapar ?
#
# WH PRP NN JJ Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya sudah makan
# kalimat referensi:  saya sudah makan
#
# PRP MD VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kenapa kamu capek ?
# kalimat referensi:  kenapa kamu capek ?
#
# WH PRP JJ Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya ada banyak kerja
# kalimat referensi:  saya ada banyak kerja
#
# PRP VB CD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya betul tidur awal
# kalimat referensi:  saya betul tidur awal
#
# PRP JJ VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  binatang apa paling kamu takut ?
# ...
#
# JJ PRP VB NN CC NN
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  salah orang peluk indonesia paling kenal jeihan
# kalimat referensi:  salah orang peluk indonesia paling kenal jeihan
#
# CD NN VB NNP RB VB NNP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  lukis jeihan indah sekali
# kalimat referensi:  lukis jeihan indah sekali
#
# VB NN JJ RB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya suka ke luk pandang alam
# kalimat referensi:  saya suka luk pandang alam
#
# PRP VB NNP VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  saya dengar cerita itu teman iwan
# kalimat referensi:  saya dengar cerita itu dari teman iwan
#
# PRP VB NN PR NN NNP
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  iwan pukul kepala untuk saya
# kalimat referensi:  iwan pukul kepala saya
#
# NNP VB NN PRP
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  pukul keras sekali
# kalimat referensi:  pukul keras sekali
#
# VB JJ RB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  pukul siswa tentang tanpa guru itu sudah lapor polisi akan
# kalimat referensi:  pukul siswa oleh guru itu sudah lapor ke polisi
#
# VB NN NN PR MD VB NN
# WER individual:  0.4444444444444444
# ----------------------------------
# kalimat prediksi:  saya tidak bisa kendara mobil
# kalimat referensi:  saya tidak bisa kendara mobil
#
# PRP NEG MD NN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  sopir angkot itu tilang atas polisi
# kalimat referensi:  sopir angkot itu tilang polisi
#
# NN NN PR VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  kendara mobil itu mabuk
# kalimat referensi:  kendara mobil itu mabuk
#
# NN NN PR JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  orang islam tidak boleh makan akan daging babi tentang tanpa
# kalimat referensi:  orang islam tidak boleh makan daging babi
#
# NN NNP RB MD VB NN NN
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  makan suka saya bakso
# kalimat referensi:  makan suka saya bakso
#
# VB JJ PRP NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  harimau binatang makan di daging
# kalimat referensi:  harimau binatang makan daging
#
# NN NN VB NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  minum suka saya cocacola
# kalimat referensi:  minum suka saya cocacola
#
# VB VB PRP NNP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kita harus minum banyak air putih
# kalimat referensi:  kita harus minum banyak air putih
#
# PRP MD VB CD NN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  tiap hari saya jalan kaki tentang tanpa kaki 2 km
# kalimat referensi:  tiap hari saya jalan-kaki kaki 2 km
#
# CD NN PRP VB NN NN CD NND
# WER individual:  0.5714285714285714
# ----------------------------------
# kalimat prediksi:  pejal kaki tidak boleh pasuk akan jalan tol tentang tanpa
# kalimat referensi:  pejal kaki tidak boleh pasuk jalan tol
#
# VB NN RB MD VB NN NN
# WER individual:  0.42857142857142855
# ----------------------------------
# kalimat prediksi:  tiap pagi saya lari keliling lapang oleh sepak bola
# kalimat referensi:  tiap pagi saya lari keliling lapang sepak bola
#
# CD NN PRP VB NN JJ NN NN
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  maradona main sepak tentang tanpa bola terhadap paling hebat dunia
# kalimat referensi:  maradona main sepak bola paling hebat di dunia
#
# NNP VB NN NN RB JJ NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  maradona main sepak tentang tanpa bola sejak umur 5 tahun sampai
# kalimat referensi:  maradona main sepak bola sejak umur 5 tahun
#
# NNP VB NN NN NN CD NN
# WER individual:  0.375
# ----------------------------------
# kalimat prediksi:  banyak orang kagum main sepak tentang tanpa bola maradona
# kalimat referensi:  banyak orang kagum dengan main sepak bola maradona
#
# CD NN JJ VB NN NN NNP
# WER individual:  0.375
# ----------------------------------
# kalimat prediksi:  siapa lari cepat demi dunia ?
# kalimat referensi:  siapa lari cepat di dunia ?
#
# SC VB JJ NN Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  saya ingin tanya kamu
# kalimat referensi:  saya ingin tanya kamu
#
# PRP RB VB PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kamu boleh tanya saya
# kalimat referensi:  kamu boleh tanya saya
#
# PRP MD VB PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak bisa jawab tanya kamu
# kalimat referensi:  saya tidak bisa jawab tanya kamu
#
# PRP NEG MD VB VB PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  semua jawab kamu salah
# kalimat referensi:  semua jawab kamu salah
#
# CD VB PRP JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  karena tidak punya uang tentang tanpa orang itu curi makan
# kalimat referensi:  karena tidak punya uang orang itu curi makan
#
# SC NEG VB NN NN PR VB VB
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  polisi usaha tangkap curi itu
# kalimat referensi:  polisi usaha tangkap curi itu
#
# NN NN VB VB PR
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  curi itu akhir seperti hasil tangkap
# kalimat referensi:  curi itu akhir hasil tangkap
#
# VB PR NN NN VB
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  mobil curi itu jual atas harga murah
# kalimat referensi:  mobil curi itu jual dengan harga murah
#
# NN VB PR VB NN JJ
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  lelaki itu usaha rampok di mobil saya untuk
# kalimat referensi:  lelaki itu usaha rampok mobil saya
#
# NN PR NN VB NN PRP
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  rampok itu usaha bunuh saya
# kalimat referensi:  rampok itu usaha bunuh saya
#
# NN PR NN VB PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak bisa bunuh akan makhluk hidup tentang tanpa
# kalimat referensi:  saya tidak bisa bunuh makhluk hidup
#
# PRP NEG MD VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  tadi malam saya tonton film india
# kalimat referensi:  tadi malam saya tonton film india
#
# NN NN PRP VB NN NNP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  banyak tonton kecewa demi film itu
# kalimat referensi:  banyak tonton kecewa dengan film itu
#
# CD VB JJ NN PR
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  celaka itu jadi tonton masyarakat
# kalimat referensi:  celaka itu jadi tonton masyarakat
#
# VB PR VB VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  jual itu tidak mau jual barang tentang tanpa dagang sejak harga murah
# kalimat referensi:  jual itu tidak mau jual barang dagang dengan harga murah
#
# VB PR NEG RB VB NN NN NN JJ
# WER individual:  0.3
# ----------------------------------
# kalimat prediksi:  beli narkoba bisa hukum
# kalimat referensi:  beli narkoba bisa hukum
#
# VB NN MD NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  beli pesawat itu laku diam diam
# kalimat referensi:  beli pesawat itu laku diam diam
#
# VB NN PR JJ RB RB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  layan restoran ini muas
# kalimat referensi:  layan di restoran ini muas
#
# VB NN PR JJ
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  layan harus layan langgan sopan
# kalimat referensi:  layan harus layan langgan dengan sopan
#
# VB MD VB VB JJ
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  mobil itu jepang
# kalimat referensi:  mobil itu buat jepang
#
# NN PR NNP
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  mobil listrik perlu waktu lama
# kalimat referensi:  buat mobil listrik perlu waktu lama
#
# NN NN MD NN JJ
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  indonesia sudah bisa mobil
# kalimat referensi:  indonesia sudah bisa buat mobil
#
# NNP MD MD NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  besok saya mau pergi bandung
# kalimat referensi:  besok saya mau pergi ke bandung
#
# NN PRP MD VB NNP
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  kamu tidak boleh pulang akan sekarang
# kalimat referensi:  kamu tidak boleh pulang sekarang
#
# PRP NEG MD VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  tiap pagi saya jalan kaki lama 30 menit
# kalimat referensi:  tiap pagi saya jalan-kaki lama 30 menit
#
# CD NN PRP VB VB JJ CD NN
# WER individual:  0.2857142857142857
# ----------------------------------
# kalimat prediksi:  karena takut dia lari
# kalimat referensi:  karena takut dia lari
#
# SC JJ PRP VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  ibu saya biasa tidur jam 10 sampai malam
# kalimat referensi:  ibu saya biasa tidur jam 10 malam
#
# NN PRP RB VB NN CD NN
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  karena senang dia senyum
# kalimat referensi:  karena senang dia senyum
#
# SC JJ PRP JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  anak perempuan itu sedih karena ayah tinggal
# kalimat referensi:  anak perempuan itu sedih karena ayah tinggal
#
# NN NN PR JJ SC NN VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya marah karena saya rasa hina dia
# kalimat referensi:  saya marah karena saya rasa hina oleh dia
#
# PRP JJ SC PRP NN JJ PRP
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  jangan khawatir saya pasti bantu kamu
# kalimat referensi:  jangan khawatir saya pasti bantu kamu
#
# NEG JJ PRP RB VB PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya bingung mengapa saya tidak boleh makan semangka
# kalimat referensi:  saya bingung mengapa saya tidak boleh makan semangka
#
# PRP VB WH PRP RB VB VB NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  tiap pagi ayah saya minum kopi dan makan nasi tentang tanpa goreng
# kalimat referensi:  tiap pagi ayah saya minum kopi dan makan nasi goreng
#
# CD NN NN PRP VB NN CC VB NN NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  adhi beli buku itu hong kong
# kalimat referensi:  adhi beli buku itu di hong kong
#
# NNP VB NN PR NNP NNP
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  saya ingin jual sepeda tentang tanpa motor saya
# kalimat referensi:  saya ingin jual sepeda motor saya
#
# PRP RB VB NN NN PRP
# WER individual:  0.3333333333333333
# ----------------------------------
# kalimat prediksi:  kakak saya beri saya hadiah
# kalimat referensi:  kakak saya beri saya hadiah
#
# NN PRP VB PRP NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  apakah kamu sudah terima akan surat presiden jokowi ?
# kalimat referensi:  apakah kamu sudah terima surat dari presiden jokowi ?
#
# SC PRP MD VB NN NNP NNP Z
# WER individual:  0.2222222222222222
# ----------------------------------
# kalimat prediksi:  jahat itu pukul saya kali kali
# kalimat referensi:  jahat itu pukul saya kali kali
#
# JJ PR VB PRP NN NND
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  saya tidak erti tanya kamu
# kalimat referensi:  saya tidak erti tanya kamu
#
# PRP NEG NN VB PRP
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  berita itu sudah tonton ribu orang
# kalimat referensi:  berita itu sudah tonton oleh ribu orang
#
# NN PR MD VB CD NN
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  apakah kamu pernah baca akan novel bahasa inggris ?
# kalimat referensi:  apakah kamu pernah baca novel bahasa inggris ?
#
# WH PRP MD VB NN NNP NNP Z
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  hp ini beli laura harga tiga juta
# kalimat referensi:  hp ini beli oleh laura dengan harga tiga juta
#
# NN PR VB NNP NN CD CD
# WER individual:  0.2222222222222222
# ----------------------------------
# kalimat prediksi:  curi itu pukul atas polisi
# kalimat referensi:  curi itu pukul oleh polisi
#
# VB PR VB NN
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  kambing itu makan atas ular
# kalimat referensi:  kambing itu makan ular
#
# NN PR VB NN
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  obat ini harus minum tiga kali hari
# kalimat referensi:  obat ini harus minum tiga kali hari
#
# NN PR MD VB CD NN NN
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  dia tanya saya mana saya lahir
# kalimat referensi:  dia tanya saya di mana saya lahir
#
# PRP VB PRP WH PRP VB
# WER individual:  0.14285714285714285
# ----------------------------------
# kalimat prediksi:  apa kamu pikir ?
# kalimat referensi:  apa kamu pikir ?
#
# WH PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  mana kamu tinggal ?
# kalimat referensi:  di mana kamu tinggal ?
#
# WH PRP VB Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  mana kamu mau pergi ?
# kalimat referensi:  ke mana kamu mau pergi ?
#
# WH PRP MD VB Z
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  mengapa kemarin kamu tidak kuliah ?
# kalimat referensi:  mengapa kemarin kamu tidak kuliah ?
#
# SC NN PRP NEG NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  bagaimana ada ibu ?
# kalimat referensi:  bagaimana ada ibu ?
#
# SC VB NN Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  jam berapa kita istirahat ?
# kalimat referensi:  jam berapa kita istirahat ?
#
# NN WH PRP VB Z
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  kapan kamu ajar ke bisindo ?
# kalimat referensi:  kapan kamu ajar bisindo ?
#
# SC PRP VB NNP Z
# WER individual:  0.2
# ----------------------------------
# kalimat prediksi:  badan saya gemuk tetapi badan sejak adik saya kurus
# kalimat referensi:  badan saya gemuk tetapi badan adik saya kurus
#
# NN PRP JJ CC NN NN PRP JJ
# WER individual:  0.125
# ----------------------------------
# kalimat prediksi:  masakan padang itu enak tetapi mahal
# kalimat referensi:  masakan padang itu enak tetapi mahal
#
# NN NNP PR JJ CC JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  dia anak baik banyak orang suka
# kalimat referensi:  dia anak baik banyak orang suka
#
# PRP NN JJ CD NN VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  artis korea itu tampan
# kalimat referensi:  artis korea itu tampan
#
# NN NNP PR JJ
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  nyanyi cantik itu bisa main akan gitar
# kalimat referensi:  nyanyi cantik itu bisa main gitar
#
# VB JJ PR MD VB NN
# WER individual:  0.16666666666666666
# ----------------------------------
# kalimat prediksi:  tulis jelek tidak bisa saya baca
# kalimat referensi:  tulis jelek tidak bisa saya baca
#
# VB JJ NEG MD PRP VB
# WER individual:  0.0
# ----------------------------------
# kalimat prediksi:  iwan pakai baju tentang tanpa merah adhi pakai baju putih tentang tanpa
# kalimat referensi:  iwan pakai baju merah adhi pakai baju putih
#
# NNP VB NN NN NNP VB NN NN
# WER individual:  0.5
# ----------------------------------
# kalimat prediksi:  tolong mati demi ac nya
# kalimat referensi:  tolong mati ac nya
#
# VB JJ NN PRP
# WER individual:  0.25
# ----------------------------------
# kalimat prediksi:  jangan duduk meja
# kalimat referensi:  jangan duduk di atas meja
#
# NEG VB NN
# WER individual:  0.4
# ----------------------------------
# BLEU Score Keseluruhan:  88.39375268663132
# WER:  0.17721897919473134
# =======

# %% [markdown]
# ### Save Prediction Ke CSV

# %%
df.to_csv('/workspace/BISINDO/Translation/dataset-ronaldi/Hasil_Prediksi.csv', index=False)

# %%
torch.cuda.empty_cache()
